# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# IMPORTED THE LIBRARIES FOR EDA

# %%
df = pd.read_csv('daily_weather.csv')

# %% [markdown]
# IMPORTED THE FILE TO PERFORM EDA AND BUILD MODELS ON

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 11 columns):
# number                    1095 non-null int64
# air_pressure_9am          1092 non-null float64
# air_temp_9am              1090 non-null float64
# avg_wind_direction_9am    1091 non-null float64
# avg_wind_speed_9am        1092 non-null float64
# max_wind_direction_9am    1092 non-null float64
# max_wind_speed_9am        1091 non-null float64
# rain_accumulation_9am     1089 non-null float64
# rain_duration_9am         1092 non-null float64
# relative_humidity_9am     1095 non-null float64
# relative_humidity_3pm     1095 non-null float64
# dtypes: float64(10), int64(1)
# memory usage: 94.2 KB

# %% [markdown]
# WE CAN OBSERVE THAT ALL COLUMNS HAVE FLOAT VALUES AND SOME FEATURES HAS NULL VALUES. THE NUMBER COLUMN HAS INTEGER VALUE BUT IT IS NOT USEFUL AND WILL BE DROPPED LATER

# %%
df.isna().sum()
# Out:
# number                    0
# air_pressure_9am          3
# air_temp_9am              5
# avg_wind_direction_9am    4
# avg_wind_speed_9am        3
# max_wind_direction_9am    3
# max_wind_speed_9am        4
# rain_accumulation_9am     6
# rain_duration_9am         3
# relative_humidity_9am     0
# relative_humidity_3pm     0
# dtype: int64

# %% [markdown]
# HERE WE CAN SEE THAT EACH COLUMNS HAS SOME NULL VALUES AND DROPPING THEM WITHOUT REPLACING WOULD NOT EFFECT THE DATASET MUCH

# %%
df.describe()
# Out:
#             number  air_pressure_9am  air_temp_9am  avg_wind_direction_9am  \
# count  1095.000000       1092.000000   1090.000000             1091.000000
# mean    547.000000        918.882551     64.933001              142.235511
# std     316.243577          3.184161     11.175514               69.137859
# min       0.000000        907.990000     36.752000               15.500000
# 25%     273.500000        916.550000     57.281000               65.972506
# 50%     547.000000        918.921045     65.715479              166.000000
# 75%     820.500000        921.160073     73.450974              191.000000
# max    1094.000000        929.320000     98.906000              343.400000
#
#        avg_wind_speed_9am  max_wind_direction_9am  max_wind_speed_9am  \
# count         1092.000000             1092.000000         1091.000000
# mean             5.508284              148.953518            7.019514
# std              4.552813               67.238013            5.598209
# ...

# %% [markdown]
# BEFORE DROPPING THE NULL VALUES CHECKING THE AGGREGATION

# %%
df = df.dropna()

# %% [markdown]
# DROPPED THE NULL VALUES

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1064 entries, 0 to 1094
# Data columns (total 11 columns):
# number                    1064 non-null int64
# air_pressure_9am          1064 non-null float64
# air_temp_9am              1064 non-null float64
# avg_wind_direction_9am    1064 non-null float64
# avg_wind_speed_9am        1064 non-null float64
# max_wind_direction_9am    1064 non-null float64
# max_wind_speed_9am        1064 non-null float64
# rain_accumulation_9am     1064 non-null float64
# rain_duration_9am         1064 non-null float64
# relative_humidity_9am     1064 non-null float64
# relative_humidity_3pm     1064 non-null float64
# dtypes: float64(10), int64(1)
# memory usage: 99.8 KB

# %%
df.describe()
# Out:
#             number  air_pressure_9am  air_temp_9am  avg_wind_direction_9am  \
# count  1064.000000       1064.000000   1064.000000             1064.000000
# mean    545.001880        918.903180     65.022609              142.306756
# std     316.796111          3.179040     11.168033               69.149472
# min       0.000000        907.990000     36.752000               15.500000
# 25%     269.750000        916.595376     57.398000               65.979244
# 50%     543.500000        918.942281     65.778479              165.937461
# 75%     819.250000        921.169054     73.530872              191.100000
# max    1094.000000        929.320000     98.906000              343.400000
#
#        avg_wind_speed_9am  max_wind_direction_9am  max_wind_speed_9am  \
# count         1064.000000             1064.000000         1064.000000
# mean             5.485793              148.480424            6.999714
# std              4.534427               67.154911            5.590790
# ...

# %% [markdown]
# HERE WE CAN SEE THAT ALL THE NULL VALUES HAVE BEEN REMOVED AND THE AGGREGATIONS HAVE NOT BEEN AFFECTED MUCH

# %%
df = df.drop(['number'], axis = 1)

# %% [markdown]
# THE NUMBER COLUMN HAS BEEN REMOVED AS IT IS NOT NECESSARY

# %%
df.describe()
# Out:
#        air_pressure_9am  air_temp_9am  avg_wind_direction_9am  \
# count       1064.000000   1064.000000             1064.000000
# mean         918.903180     65.022609              142.306756
# std            3.179040     11.168033               69.149472
# min          907.990000     36.752000               15.500000
# 25%          916.595376     57.398000               65.979244
# 50%          918.942281     65.778479              165.937461
# 75%          921.169054     73.530872              191.100000
# max          929.320000     98.906000              343.400000
#
#        avg_wind_speed_9am  max_wind_direction_9am  max_wind_speed_9am  \
# count         1064.000000             1064.000000         1064.000000
# mean             5.485793              148.480424            6.999714
# std              4.534427               67.154911            5.590790
# min              0.693451               28.900000            1.185578
# ...

# %%
df.columns
# Out:
# Index(['air_pressure_9am', 'air_temp_9am', 'avg_wind_direction_9am',
#        'avg_wind_speed_9am', 'max_wind_direction_9am', 'max_wind_speed_9am',
#        'rain_accumulation_9am', 'rain_duration_9am', 'relative_humidity_9am',
#        'relative_humidity_3pm'],
#       dtype='object')

# %% [markdown]
# ALL THE COLUMNS THAT ARE LEFT

# %% [markdown]
# 1. A. BOX PLOT

# %% [markdown]
# HERE WE HAVE PLOTTED THE BOXPLOT OF THE INDEPENDENT VARIABLES. THESE ARE NOT PLOTTED AGAINST THE TARGET VARIABLE AS IT IS NOT CATEGORICAL IN NATURE.

# %%
plt.figure(figsize=(15,3))

plt.subplot(1,3,1)
plt.title('air_pressure')
sns.boxplot(y='air_pressure_9am',data = df)


plt.subplot(1,3,2)
plt.title('air_temp')
sns.boxplot(y='air_temp_9am',data = df)


plt.subplot(1,3,3)
plt.title('avg_wind_direction')
sns.boxplot(y='avg_wind_direction_9am',data = df)

plt.figure(figsize=(15,3))

plt.subplot(1,3,1)
plt.title('avg_wind_speed')
sns.boxplot(y='avg_wind_speed_9am',data = df)


plt.subplot(1,3,2)
plt.title('max_wind_direction')
sns.boxplot(y='max_wind_direction_9am',data = df)


plt.subplot(1,3,3)
plt.title('max_wind_speed')
sns.boxplot(y='max_wind_speed_9am',data = df)

plt.figure(figsize=(15,3))

plt.subplot(1,3,1)
plt.title('rain_accumulation')
sns.boxplot(y='rain_accumulation_9am',data = df)


plt.subplot(1,3,2)
plt.title('rain_duration')
sns.boxplot(y='rain_duration_9am',data = df)


plt.subplot(1,3,3)
plt.title('relative_humidity')
sns.boxplot(y='relative_humidity_9am',data = df)

# %% [markdown]
# 1. HERE WE OBSERVE THAT AIR PRESSURE, AIR TEMPERATURE, AVERAGE WIND SPEED, MAX WIND SPEED, RAIN ACCUMULATION, RAIN DURATION AND RELATIVE HUMIDITY HAVE SOME OUTLIERS
#
# 2. ALSO IT IS OBSERVED THAT RAIN ACCUMULATION AND RAIN DURATION DATA HAS MANY VALUES AROUND ZERO
#
# 3. IN AVERAGE WIND DIRECTION, AVERAGE WIND SPEED AND RELATIVE HUMIDITY THE VALUES ARE MORE CONCENTRATED TOWARDS THE LOWER PART

# %% [markdown]
# 1. B. HISTOGRAM

# %%
plt.hist(df['relative_humidity_3pm'], bins=10)
# Out:
# (array([136., 343., 115.,  79.,  92., 106.,  73.,  39.,  39.,  42.]),
#  array([ 5.3  , 13.995, 22.69 , 31.385, 40.08 , 48.775, 57.47 , 66.165,
#         74.86 , 83.555, 92.25 ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# HERE WE CAN OBSERVE THAT MOST OF THE VALUES ARE CONCENTRATED IN THE RANGE OF 10 TO 20, OTHERWISE THE OTHER OCCURENCES ARE QUITE SPREAD IN AN AVERAGE MANNER AND GENTLY THE OCCURENCES GOING DOWN

# %% [markdown]
# 1. C. DISTRIBUTION PLOT

# %%
sns.distplot(df['relative_humidity_3pm'],bins=10)

# %% [markdown]
# HERE IT IS OBSERVED THAT THE DATA IS RIGHT SKEWED

# %% [markdown]
# 1. D. AGGREGATION

# %%
df.describe()
# Out:
#        air_pressure_9am  air_temp_9am  avg_wind_direction_9am  \
# count       1064.000000   1064.000000             1064.000000
# mean         918.903180     65.022609              142.306756
# std            3.179040     11.168033               69.149472
# min          907.990000     36.752000               15.500000
# 25%          916.595376     57.398000               65.979244
# 50%          918.942281     65.778479              165.937461
# 75%          921.169054     73.530872              191.100000
# max          929.320000     98.906000              343.400000
#
#        avg_wind_speed_9am  max_wind_direction_9am  max_wind_speed_9am  \
# count         1064.000000             1064.000000         1064.000000
# mean             5.485793              148.480424            6.999714
# std              4.534427               67.154911            5.590790
# min              0.693451               28.900000            1.185578
# ...

# %% [markdown]
# HERE WE CAN SEE THE DIFFERENT AGGREGATE VALUES OF EACH COLUMN. ALSO WE SEE THAT IN RAIN ACCUMULATION AND RAIN DURATION MORE THAN 75% OF THE DATA HAS ZERO. ALSO THE STANDARD DEVIATION IN RAIN DURATION IS TOO HIGH.

# %% [markdown]
# 1. E. UNIQUE VALUES ACROSS ALL COLUMNS

# %%
df.nunique()
# Out:
# air_pressure_9am          1042
# air_temp_9am              1063
# avg_wind_direction_9am     982
# avg_wind_speed_9am        1059
# max_wind_direction_9am     965
# max_wind_speed_9am        1058
# rain_accumulation_9am       94
# rain_duration_9am          135
# relative_humidity_9am     1063
# relative_humidity_3pm     1063
# dtype: int64

# %% [markdown]
# HERE WE OBSERVE THAT RAIN ACCUMULATION AND RAIN DURATION HAS LESS UNIQUE VALUES

# %% [markdown]
# 1. F. DUPLICATE VALUES ACROSS ALL COLUMNS

# %%
df.loc[df.duplicated()]
# Out:
#      air_pressure_9am  air_temp_9am  avg_wind_direction_9am  \
# 543            921.65         62.87                    56.7
#
#      avg_wind_speed_9am  max_wind_direction_9am  max_wind_speed_9am  \
# 543           10.714943                    77.3           13.712442
#
#      rain_accumulation_9am  rain_duration_9am  relative_humidity_9am  \
# 543                    0.0                0.0                  21.11
#
#      relative_humidity_3pm
# 543                  20.89

# %% [markdown]
# THE ABOVE ROW IS A DUPLICATE

# %% [markdown]
# 1. G. CORRELATION HEATMAP

# %%
plt.figure(figsize = (20,20))

sns.heatmap(df.corr(),annot=True)

# %% [markdown]
# FROM THE ABOVE HEATMAP IT IS SEEN THAT AVG WIND SPEED, MAXIMUM WIND SPEED AND RAIN ACCUMULATION IS VERY THINLY CORRELATED TO TARGET VARIABLE

# %% [markdown]
# 1. H. REGRESSION PLOT

# %%
plt.figure(figsize=(15,3))

plt.subplot(1,3,1)
sns.regplot(x="air_pressure_9am", y="relative_humidity_3pm", data=df);


plt.subplot(1,3,2)
sns.regplot(x="air_temp_9am", y="relative_humidity_3pm", data=df);


plt.subplot(1,3,3)
sns.regplot(x="avg_wind_direction_9am", y="relative_humidity_3pm", data=df);

plt.figure(figsize=(15,3))

plt.subplot(1,3,1)
sns.regplot(x="avg_wind_speed_9am", y="relative_humidity_3pm", data=df);


plt.subplot(1,3,2)
sns.regplot(x="max_wind_direction_9am", y="relative_humidity_3pm", data=df);


plt.subplot(1,3,3)
sns.regplot(x="max_wind_speed_9am", y="relative_humidity_3pm", data=df);

plt.figure(figsize=(15,3))

plt.subplot(1,3,1)
sns.regplot(x="rain_accumulation_9am", y="relative_humidity_3pm", data=df);


plt.subplot(1,3,2)
sns.regplot(x="rain_duration_9am", y="relative_humidity_3pm", data=df);


plt.subplot(1,3,3)
sns.regplot(x="relative_humidity_9am", y="relative_humidity_3pm", data=df);

# %% [markdown]
# 1. FROM THE ABOVE WE CAN SEE THAT CHANGE IN AIR PRESSURE AND AIR TEMPERATURE SIGNIFICANTLY AFFECTS THE RELATIVE HUMIDITY
# 2. AVERAGE WIND DIRECTION, AVG WIND SPEED, MAX WIND DIRECTION AND MAXIMUM WIND SPEED ALSO SOMEWHAT AFFECTS THE RELATIVE HUMIDITY.

# %% [markdown]
# 1. I. BAR PLOT

# %% [markdown]
# CANNOT PLOT BAR PLOT AGAINST FLOAT VALUES

# %% [markdown]
# 1. J. PAIR PLOT

# %%
sns.pairplot(df)

# %% [markdown]
# 2. DROP DUPLICATE ROWS : WE HAVE ONE DUPLICATE ROW

# %%
df = df.drop_duplicates()

# %%
df.loc[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [air_pressure_9am, air_temp_9am, avg_wind_direction_9am, avg_wind_speed_9am, max_wind_direction_9am, max_wind_speed_9am, rain_accumulation_9am, rain_duration_9am, relative_humidity_9am, relative_humidity_3pm]
# Index: []

# %% [markdown]
# DROPPED THE DUPLICATE ROW

# %% [markdown]
# 3. DROPPING NON ESSENTIAL FEATURES

# %%
df = df.drop(['rain_accumulation_9am','rain_duration_9am'], axis = 1)

# %% [markdown]
# DROPPED THE ABOVE FEATURE AS IT IS NOT IDEAL FOR MODEL PREDICTION. IT HAS MORE THAN 75% ZERO VALUES IN IT

# %%
df.describe()
# Out:
#        air_pressure_9am  air_temp_9am  avg_wind_direction_9am  \
# count       1063.000000   1063.000000             1063.000000
# mean         918.900596     65.024635              142.387289
# std            3.179418     11.173095               69.132082
# min          907.990000     36.752000               15.500000
# 25%          916.590752     57.398000               66.109634
# 50%          918.940000     65.822000              166.000000
# 75%          921.164515     73.559248              191.100000
# max          929.320000     98.906000              343.400000
#
#        avg_wind_speed_9am  max_wind_direction_9am  max_wind_speed_9am  \
# count         1063.000000             1063.000000         1063.000000
# mean             5.480874              148.547386            6.993399
# std              4.533720               67.150973            5.589624
# min              0.693451               28.900000            1.185578
# ...

# %% [markdown]
# 4. REPLACE OUTLIERS WITH NULL AND REPLACE NULLS WITH CENTRAL TENDENCIES

# %% [markdown]
# WOULD NOT REPLACE THE OUTLIERS AS IT AFFECTS THE MODEL

# %% [markdown]
# 5. CALCULATING Z-SCORE TO VALIDATE THAT THERE ARE NO OUTLIERS

# %% [markdown]
# 7. ADD YOUR VIEW OF EDA

# %%
plt.figure(figsize=(15,3))

plt.subplot(1,3,1)
sns.scatterplot(x="air_pressure_9am", y="relative_humidity_3pm", data=df);


plt.subplot(1,3,2)
sns.scatterplot(x="air_temp_9am", y="relative_humidity_3pm", data=df);


plt.subplot(1,3,3)
sns.scatterplot(x="avg_wind_direction_9am", y="relative_humidity_3pm", data=df);

plt.figure(figsize=(15,3))


plt.subplot(1,3,1)
sns.scatterplot(x="max_wind_direction_9am", y="relative_humidity_3pm", data=df);


plt.subplot(1,3,2)
sns.scatterplot(x="relative_humidity_9am", y="relative_humidity_3pm", data=df);


plt.subplot(1,3,3)
sns.scatterplot(x="avg_wind_speed_9am", y="relative_humidity_3pm", data=df);

# %% [markdown]
# HERE IT IS OBSERVED THAT THE TEMPERATURE AND RELATIVE HUMIDITY(MORNING) IS QUITE CONSTANTLY RELATED TO RELATIVE HUMIDITY(AFTERNOON)

# %% [markdown]
# 8. BUILD A MODEL OF YOUR CHOICE

# %%
X = df.drop('relative_humidity_3pm',axis = 1)
Y = df['relative_humidity_3pm']

# %% [markdown]
# SEPARATE THE X(INDEPENDENT) AND Y(DEPENDENT) VARIABLES

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.3, random_state = 50)

# %% [markdown]
# SPLITTING THE DATA INTO TRAIN AND TEST

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.model_selection import KFold
kf = KFold(n_splits=5)
kf
from sklearn.model_selection import cross_val_score

# %% [markdown]
# IMPORTING THE LIBRARIES FOR BUILDING MODEL AND CROSS VALIDATION

# %%
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
import xgboost

# %%
from sklearn import metrics
import math

# %% [markdown]
# LIBRARIES FOR CALCULATING DIFFERENT ERROR METRICS AND R2

# %% [markdown]
# LINEAR REGRESSION MODEL

# %%
from sklearn import model_selection
lr = LinearRegression()
lr = lr.fit(X_train, Y_train)
results = model_selection.cross_val_score(lr, X_train, Y_train)
print(results)
Y_pred = lr.predict(X_test)
# Out:
# [0.82074138 0.78286504 0.76745093 0.75699894 0.79402238]

# %%
params = {'copy_X': [0, 1], 
              'fit_intercept': [0,1],
              'n_jobs':[3,4,5,6,7],
              'normalize': [0,1]}

# %%
random_search=RandomizedSearchCV(lr,param_distributions=params,n_iter=5,n_jobs=-1,cv=5)

# %%
random_search.fit(X_train,Y_train)
# Out:
# RandomizedSearchCV(cv=5, error_score=nan,
#                    estimator=LinearRegression(copy_X=True, fit_intercept=True,
#                                               n_jobs=None, normalize=False),
#                    iid='deprecated', n_iter=5, n_jobs=-1,
#                    param_distributions={'copy_X': [0, 1],
#                                         'fit_intercept': [0, 1],
#                                         'n_jobs': [3, 4, 5, 6, 7],
#                                         'normalize': [0, 1]},
#                    pre_dispatch='2*n_jobs', random_state=None, refit=True,
#                    return_train_score=False, scoring=None, verbose=0)

# %%
random_search.best_estimator_
# Out:
# LinearRegression(copy_X=1, fit_intercept=1, n_jobs=4, normalize=0)

# %%
regressor=xgboost.XGBRegressor(copy_X=1, fit_intercept=1, n_jobs=4, normalize=0)

# %% [markdown]
# DECISION TREE

# %%
dt = DecisionTreeRegressor()
dt = dt.fit(X_train, Y_train)
results = model_selection.cross_val_score(dt, X_train, Y_train)
print(results)
Y_pred1 = dt.predict(X_test)
# Out:
# [0.65915522 0.65925425 0.76033234 0.63202209 0.69242681]

# %%
params = {'max_depth': [3, 5, 6, 7, 8], 
              'max_features': [2,4,6,7,8,9],
              'min_samples_split': [2,3, 5, 6, 7]}

# %%
random_search=RandomizedSearchCV(dt,param_distributions=params,n_iter=5,n_jobs=-1,cv=5)

# %%
random_search.fit(X_train,Y_train)
# Out:
# RandomizedSearchCV(cv=5, error_score=nan,
#                    estimator=DecisionTreeRegressor(ccp_alpha=0.0,
#                                                    criterion='mse',
#                                                    max_depth=None,
#                                                    max_features=None,
#                                                    max_leaf_nodes=None,
#                                                    min_impurity_decrease=0.0,
#                                                    min_impurity_split=None,
#                                                    min_samples_leaf=1,
#                                                    min_samples_split=2,
#                                                    min_weight_fraction_leaf=0.0,
#                                                    presort='deprecated',
#                                                    random_state=None,
# ...

# %%
random_search.best_estimator_
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=5,
#                       max_features=7, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=7,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')

# %%
regressor=xgboost.XGBRegressor(ccp_alpha=0.0, criterion='mse', max_depth=5,
                      max_features=7, max_leaf_nodes=None,
                      min_impurity_decrease=0.0, min_impurity_split=None,
                      min_samples_leaf=1, min_samples_split=7,
                      min_weight_fraction_leaf=0.0, presort='deprecated',
                      random_state=None, splitter='best')

# %% [markdown]
# RANDOM FOREST REGRESSION

# %%
rf = RandomForestRegressor(n_estimators = 50)
rf = rf.fit(X_train, Y_train)
results = model_selection.cross_val_score(rf, X_train, Y_train)
print(results)
Y_pred2 = rf.predict(X_test)
# Out:
# [0.82042493 0.80534007 0.83667853 0.80503    0.85112818]

# %%
params = {'max_depth': [3, 5, 6, 7, 8],
              'n_estimators':[50,100],
              'min_samples_split': [3, 5, 6, 7]}

# %%
random_search=RandomizedSearchCV(rf,param_distributions=params,n_iter=5,n_jobs=-1,cv=5)

# %%
random_search.fit(X_train,Y_train)
# Out:
# RandomizedSearchCV(cv=5, error_score=nan,
#                    estimator=RandomForestRegressor(bootstrap=True,
#                                                    ccp_alpha=0.0,
#                                                    criterion='mse',
#                                                    max_depth=None,
#                                                    max_features='auto',
#                                                    max_leaf_nodes=None,
#                                                    max_samples=None,
#                                                    min_impurity_decrease=0.0,
#                                                    min_impurity_split=None,
#                                                    min_samples_leaf=1,
#                                                    min_samples_split=2,
#                                                    min_weight_fraction_leaf=0.0,
# ...

# %%
random_search.best_estimator_
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=7, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=7, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
regressor=xgboost.XGBRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
                      max_depth=7, max_features='auto', max_leaf_nodes=None,
                      max_samples=None, min_impurity_decrease=0.0,
                      min_impurity_split=None, min_samples_leaf=1,
                      min_samples_split=7, min_weight_fraction_leaf=0.0,
                      n_estimators=100, n_jobs=None, oob_score=False,
                      random_state=None, verbose=0, warm_start=False)

# %% [markdown]
# SVM

# %%
svm = SVR()
svm = svm.fit(X_train, Y_train)
results = model_selection.cross_val_score(svm, X_train, Y_train)
print(results)
Y_pred3 = svm.predict(X_test)
# Out:
# [ 0.02221492 -0.02501882 -0.09661826  0.04226809  0.08640779]

# %%
param_grid = {}

# %%
random_search=GridSearchCV(svm,param_grid,n_jobs=-1,cv=5)

# %%
random_search.fit(X_train,Y_train)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=SVR(C=1.0, cache_size=200, coef0=0.0, degree=3,
#                            epsilon=0.1, gamma='scale', kernel='rbf',
#                            max_iter=-1, shrinking=True, tol=0.001,
#                            verbose=False),
#              iid='deprecated', n_jobs=-1, param_grid={},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
random_search.best_estimator_
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
regressor=xgboost.XGBRegressor(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
    kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %% [markdown]
# ERROR METRICS

# %%
def mean_absolute_percentage_error(Y_true, Y_predict):
    Y_true, Y_predict = np.array(Y_true), np.array(Y_predict)
    return np.mean(np.abs((Y_true-Y_predict) / Y_true)) * 100

# %%
def mean_percentage_error(Y_true, Y_predict):
    Y_true, Y_predict = np.array(Y_true), np.array(Y_predict)
    return np.mean((Y_true-Y_predict) / Y_true) * 100

# %%
mae_lr = round(metrics.mean_absolute_error(Y_test, Y_pred), 4) 
mse_lr = round(metrics.mean_squared_error(Y_test, Y_pred), 4)
rmse_lr = round(math.sqrt(mse_lr), 4)
mpe_lr = round(mean_percentage_error(Y_test, Y_pred), 4)
mape_lr = round(mean_absolute_percentage_error(Y_test, Y_pred), 4)
r2_lr = round(metrics.r2_score(Y_test, Y_pred), 4)

# %%
mae_dt = round(metrics.mean_absolute_error(Y_test, Y_pred1), 4) 
mse_dt = round(metrics.mean_squared_error(Y_test, Y_pred1), 4)
rmse_dt = round(math.sqrt(mse_dt), 4)
mpe_dt = round(mean_percentage_error(Y_test, Y_pred1), 4)
mape_dt = round(mean_absolute_percentage_error(Y_test, Y_pred1), 4)
r2_dt = round(metrics.r2_score(Y_test, Y_pred1), 4)

# %%
mae_rf = round(metrics.mean_absolute_error(Y_test, Y_pred2), 4) 
mse_rf = round(metrics.mean_squared_error(Y_test, Y_pred2), 4)
rmse_rf = round(math.sqrt(mse_rf), 4)
mpe_rf = round(mean_percentage_error(Y_test, Y_pred2), 4)
mape_rf = round(mean_absolute_percentage_error(Y_test, Y_pred2), 4)
r2_rf = round(metrics.r2_score(Y_test, Y_pred2), 4)

# %%
mae_svm = round(metrics.mean_absolute_error(Y_test, Y_pred3), 4) 
mse_svm = round(metrics.mean_squared_error(Y_test, Y_pred3), 4)
rmse_svm = round(math.sqrt(mse_svm), 4)
mpe_svm = round(mean_percentage_error(Y_test, Y_pred3), 4)
mape_svm = round(mean_absolute_percentage_error(Y_test, Y_pred3), 4)
r2_svm = round(metrics.r2_score(Y_test, Y_pred3), 4)

# %%
compare_models = pd.DataFrame( 
    {  'Model' : ['LinReg','DTree','RanFor','SVM',],
        'R2'   : [r2_lr, r2_dt, r2_rf, r2_svm],
        'MAE'  : [mae_lr, mae_dt, mae_rf, mae_svm], 
        'MSE'  : [mse_lr, mse_dt, mse_rf, mse_svm],
        'RMSE'  : [rmse_lr, rmse_dt, rmse_rf, rmse_svm],
        'MPE'  : [mpe_lr, mpe_dt, mpe_rf, mpe_svm],
        'MAPE'  : [mape_lr, mape_dt, mape_rf, mape_svm]
    }) 
  
print(compare_models)
# Out:
#     Model      R2      MAE       MSE     RMSE      MPE     MAPE
# 0  LinReg  0.8161   7.2790  100.4735  10.0236 -10.4047  24.9189
# 1   DTree  0.6410   9.5186  196.1735  14.0062  -9.7535  28.4215
# 2  RanFor  0.8221   6.9108   97.2122   9.8596  -6.1168  20.9003
# 3     SVM  0.0138  17.2754  538.9238  23.2147  -4.0442  48.6656

# %% [markdown]
# HERE WE OBSERVE THAT THE RANDOM FOREST MODEL HAS THE BEST R2 SCORE AND ALSO HAS THE LEAST ERROR. SO WE USE THIS TO PREDICT

# %% [markdown]
# 13. PREDICTION

# %%
DataFrame = pd.DataFrame({'Actual' : Y_test,'Predicted':Y_pred2})
DataFrame
# Out:
#          Actual  Predicted
# 186   52.970000  45.215600
# 1021  21.598433  27.390553
# 225   41.570000  40.801321
# 780   38.450000  20.430853
# 492   12.520000  11.205752
# ...         ...        ...
# 191   13.270000  16.018294
# 922   78.720000  70.919800
# 195   18.272918  22.985007
# 287   53.670000  59.851600
# 549   17.525930  17.731028
#
# [319 rows x 2 columns]

# %%
plt.plot(np.unique(Y_pred),color='green')


plt.plot(np.unique(Y_pred1),color='red')


plt.plot(np.unique(Y_pred2),color='blue')


plt.plot(np.unique(Y_pred3),color='yellow')


plt.plot(np.unique(Y_test),color='black')

plt.show()

# %% [markdown]
# HERE THE GREEN AND BLUE LINES ARE NEAREST TO THE ACTUAL VALUE BUT THE BLUE LINE IS NEAREST TO THE LINE OF BEST FIT
